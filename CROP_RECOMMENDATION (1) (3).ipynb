# %% [markdown]
# <h1>CROP RECOMMENDATION</h1>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from ipywidgets import interact
print("Successfully Loaded")
# Out:
# Successfully Loaded

# %%
# %pip install matplotlib seaborn ipywidgets
print("Installed Successfully")
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Installed Successfully

# %%
df=pd.read_csv('Crop_recommendation.csv')
print("csv is loaded")
# Out:
# csv is loaded

# %%
print("Shape of the dataset:",df.shape)
# Out:
# Shape of the dataset: (2200, 8)

# %%
print("Head of the dataset:")
df.head()
# Out:
# Head of the dataset:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
#Describe statistical details of the data

df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
#Checking missing/null values

print("Missing/null value in the our set:")
df.isnull().sum()
# Out:
# Missing/null value in the our set:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
#Check the unique value in the label crops

df['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# chickpea       100
# kidneybeans    100
# pigeonpeas     100
# mothbeans      100
# mungbean       100
# blackgram      100
# lentil         100
# pomegranate    100
# banana         100
# mango          100
# grapes         100
# watermelon     100
# muskmelon      100
# apple          100
# orange         100
# papaya         100
# coconut        100
# cotton         100
# jute           100
# coffee         100
# Name: count, dtype: int64

# %%
#Check all the summary and climate variables

print("Average Ratio of Nitrogen in the soil : {0:.2f}".format(df['N'].mean()))
print("Average Ratio of Phosphorous in the soil : {0:.2f}".format(df['P'].mean()))
print("Average Ratio of Potassium in the soil : {0:.2f}".format(df['K'].mean()))
print("Average Temperature in celsius : {0:.2f}".format(df['temperature'].mean()))
print("Average Humidity in the soil : {0:.2f}".format(df['humidity'].mean()))
print("Average Ph_scale in the soil : {0:.2f}".format(df['ph'].mean()))
print("Average Rain_fall in the soil : {0:.2f}".format(df['rainfall'].mean()))
# Out:
# Average Ratio of Nitrogen in the soil : 50.55
# Average Ratio of Phosphorous in the soil : 53.36
# Average Ratio of Potassium in the soil : 48.15
# Average Temperature in celsius : 25.62
# Average Humidity in the soil : 71.48
# Average Ph_scale in the soil : 6.47
# Average Rain_fall in the soil : 103.46

# %% [markdown]
# <h1>Crop Nutrient and Environmental Requirements Summary</h1>

# %%
from ipywidgets import interact
@interact
def summary(crops=list(df['label'].value_counts().index)):
    x=df[df['label'] == crops]
    print("------------------------------------------------")
    print("Statistics for Nitrogen")
    print("Minimum Nitrogen required:", x['N'].min())
    print("Average Nitrogen required:", x['N'].mean())
    print("Maximum Nitrogen required:", x['N'].max())
    print("------------------------------------------------")
    print("Statistics for Phosphorous")
    print("Minimum Phosphorous required:", x['P'].min())
    print("Average Phosphorous required:",x['P'].mean())
    print("Maximum Phosphorous required:",x['P'].max())
    print("------------------------------------------------")
    print("Statistics for Potassium")
    print("Minimum Potassium required:",x['K'].min())
    print("Average Potassium required:",x['K'].mean())
    print("Maximum Potassium required:",x['K'].max())
    print("------------------------------------------------")
    print("Statistics for Temperature")
    print("Minimum Temperature required:{0:.2f}".format(x['temperature'].min()))
    print("Average Temperature required:{0:.2f}".format(x['temperature'].mean()))
    print("Maximum Temperature required:{0:.2f}".format(x['temperature'].max()))
    print("------------------------------------------------")
    print("Statistics for Humidity")
    print("Minimum Humidity required:{0:.2f}".format(x['humidity'].min()))
    print("Average Humidity required:{0:.2f}".format(x['humidity'].mean()))
    print("Maximum Humidity required:{0:.2f}".format(x['humidity'].max()))
    print("------------------------------------------------")
    print("Statistics for Phscale")
    print("Minimum Phscale required:{0:.2f}".format(x['ph'].min()))
    print("Average Phscale required:{0:.2f}".format(x['ph'].mean()))
    print("Maximum Phscale require:{0:.2f}".format(x['ph'].max()))
    print("------------------------------------------------")
    print("Statistics for Rainfall")
    print("Minimum Rainfall required:{0:.2f}".format(x['rainfall'].min()))
    print("Average Rainfall required:{0:.2f}".format(x['rainfall'].mean()))
    print("Maximum Rainfall required:{0:.2f}".format(x['rainfall'].max()))
# Out:
# interactive(children=(Dropdown(description='crops', options=('rice', 'maize', 'chickpea', 'kidneybeans', 'pige…

# %% [markdown]
# <h1>Comparison of Soil and Weather Requirements Across Crops</h1>

# %%
#Now comparing the requirement Soil minerals and weather conditions of different crops

@interact
def compare (conditions = ['N','P','K','temperature','ph','humidity','rainfall']):
    print("Average Value for",conditions,"is {0:.2f}".format(df[conditions].mean()))
    print("-------------------------------------------------------------------------")
    print("Rice : {0:.2f}".format(df[(df['label'] == 'rice')][conditions].mean()))
    print("Maize : {0:.2f}".format(df[(df['label'] == 'maize')][conditions].mean()))
    print("Jute : {0:.2f}".format(df[(df['label'] == 'jute')][conditions].mean()))
    print("Cotton : {0:.2f}".format(df[(df['label'] == 'cotton')][conditions].mean()))
    print("Coconut :{0:.2f}".format(df[(df['label'] == 'coconut')][conditions].mean()))
    print("Papaya :{0:.2f}".format(df[(df['label'] == 'papaya')][conditions].mean()))
    print("Orange :{0:.2f}".format(df[(df['label'] == 'orange')][conditions].mean()))
    print("Apple :{0:.2f}".format(df[(df['label'] == 'apple')][conditions].mean()))
    print("Muskmelon :{0:.2f}".format(df[(df['label'] =='muskmelon')][conditions].mean()))
    print("Watermelon:{0:.2f}".format(df[(df['label'] =='watermelon')][conditions].mean()))
    print("Grapes:{0:.2f}".format(df[(df['label'] =='grapes')][conditions].mean()))
    print("Mango:{0:.2f}".format(df[(df['label']=='mango')][conditions].mean()))
    print("Banana:{0:.2f}".format(df[(df['label']=='banana')][conditions].mean()))
    print("Pomegranate :{0:.2f}".format(df[(df['label']=='pomegranate')][conditions].mean()))
    print("Lentil :{0:.2f}".format(df[(df['label']=='lentil')][conditions].mean()))
    print("Blackgram:{0:.2f}".format(df[(df['label']=='blackgram')][conditions].mean()))
    print("Mungbean:{0:.2f}".format(df[(df['label']== 'mungbean')][conditions].mean()))
    print("Mothbeans:{0:.2f}".format(df[(df['label']=='mothbeans')][conditions].mean()))
    print("Pigeonpeas:{0:.2f}".format(df[(df['label']=='pigeonbeans')][conditions].mean()))
    print("Kidneybeans:{0:.2f}".format(df[(df['label']=='kidneybeans')][conditions].mean()))
    print("Chickpea:{0:.2f}".format(df[(df['label']=='chickpea')][conditions].mean()))
    print("Coffee:{0:.2f}".format(df[(df['label']=='coffee')][conditions].mean()))
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'ph', 'humidit…

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'df' is already defined and contains your data

# Function to plot average values for a selected condition
def plot_average(condition):
    # Calculate average for each crop
    averages = df.groupby('label')[condition].mean().sort_values()
    
    # Create a bar plot
    plt.figure(figsize=(10, 6))
    averages.plot(kind='bar', color='skyblue')
    plt.title(f'Average {condition.capitalize()} Requirement for Different Crops', fontsize=16)
    plt.xlabel('Crops', fontsize=14)
    plt.ylabel(f'Average {condition.capitalize()}', fontsize=14)
    plt.xticks(rotation=45)
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()

# List of conditions to plot
conditions = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']

# Generate plots for all conditions
for condition in conditions:
    plot_average(condition)

# %%
# Function to plot pie chart for average values of a selected condition
def plot_pie_chart(condition):
    # Calculate average for each crop
    averages = df.groupby('label')[condition].mean()
    
    # Create a pie chart
    plt.figure(figsize=(8, 8))
    plt.pie(averages, labels=averages.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
    plt.title(f'Average {condition.capitalize()} Requirement Distribution Among Crops', fontsize=16)
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

# List of conditions to plot
conditions = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']

# Generate pie charts for all conditions
for condition in conditions:
    plot_pie_chart(condition)

# %%
# Function to plot line chart for average values of a selected condition
def plot_line_chart(condition):
    # Calculate average for each crop
    averages = df.groupby('label')[condition].mean()
    
    # Create a line chart
    plt.figure(figsize=(10, 6))
    plt.plot(averages.index, averages, marker='o')
    plt.title(f'Average {condition.capitalize()} Requirement by Crop', fontsize=16)
    plt.xlabel('Crops', fontsize=12)
    plt.ylabel(f'Average {condition.capitalize()}', fontsize=12)
    plt.xticks(rotation=45)
    plt.grid()
    plt.tight_layout()
    plt.show()

# List of conditions to plot
conditions = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']

# Generate line charts for all conditions
for condition in conditions:
    plot_line_chart(condition)

# %% [markdown]
# <h1>Categorization of Crops Based on Soil and Weather Conditions</h1>

# %%
from ipywidgets import interact

@interact
def compare(conditions=['N', 'P', 'K', 'temperature', 'ph', 'humidity', 'rainfall']):
    # Calculate the average for the selected condition
    average_value = df[conditions].mean()
    
    # Print crops requiring greater than average
    print(f"Crops which require greater than average {conditions} ({average_value:.2f}):\n")
    greater_than_avg = df[df[conditions] > average_value]['label'].unique()
    print(greater_than_avg)
    
    print("--------------------------------------------------------------------------------")
    
    # Print crops requiring less than or equal to average
    print(f"Crops which require less than or equal to average {conditions} ({average_value:.2f}):\n")
    less_than_equal_avg = df[df[conditions] <= average_value]['label'].unique()
    print(less_than_equal_avg)
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'ph', 'humidit…

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# Replace infinite values with NaN
df.replace([np.inf, -np.inf], np.nan, inplace=True)

plt.figure(figsize=(28, 7))

# Nitrogen Distribution
plt.subplot(2, 4, 1)
sb.histplot(df['N'], kde=True, color='orange', bins=30)
plt.xlabel('Ratio of Nitrogen', fontsize=12)
plt.grid()

# Phosphorous Distribution
plt.subplot(2, 4, 2)
sb.histplot(df['P'], kde=True, color='red', bins=30)
plt.xlabel('Ratio of Phosphorous', fontsize=12)
plt.grid()

# Potassium Distribution
plt.subplot(2, 4, 3)
sb.histplot(df['K'], kde=True, color='blue', bins=30)
plt.xlabel('Ratio of Potassium', fontsize=12)
plt.grid()

# Temperature Distribution
plt.subplot(2, 4, 4)
sb.histplot(df['temperature'], kde=True, color='purple', bins=30)
plt.xlabel('Temperature (°C)', fontsize=12)
plt.grid()

# Humidity Distribution
plt.subplot(2, 4, 5)
sb.histplot(df['humidity'], kde=True, color='green', bins=30)
plt.xlabel('Humidity (%)', fontsize=12)
plt.grid()

# pH Distribution
plt.subplot(2, 4, 6)
sb.histplot(df['ph'], kde=True, color='pink', bins=30)
plt.xlabel('pH Scale', fontsize=12)
plt.grid()

# Rainfall Distribution
plt.subplot(2, 4, 7)
sb.histplot(df['rainfall'], kde=True, color='violet', bins=30)
plt.xlabel('Rainfall (mm)', fontsize=12)
plt.grid()

plt.tight_layout()  # Adjusts subplot parameters to give specified padding
plt.show()

# %%
print("Crops Based on Specific Conditions")
print("---------------------------------------------------------------")
print("Crops requiring very high nitrogen content (N > 120):", df[df['N'] > 120]['label'].unique())
print("Crops requiring very high phosphorous content (P > 100):", df[df['P'] > 100]['label'].unique())
print("Crops requiring very high potassium content (K > 200):", df[df['K'] > 200]['label'].unique())
print("Crops requiring very high rainfall (rainfall > 200mm):", df[df['rainfall'] > 200]['label'].unique())
print("Crops requiring very low temperature (temperature < 10°C):", df[df['temperature'] < 10]['label'].unique())
print("Crops requiring very high temperature (temperature > 40°C):", df[df['temperature'] > 40]['label'].unique())
print("Crops requiring very low humidity (humidity < 20%):", df[df['humidity'] < 20]['label'].unique())
print("Crops requiring very low pH (pH < 4):", df[df['ph'] < 4]['label'].unique())
print("Crops requiring very high pH (pH > 9):", df[df['ph'] > 9]['label'].unique())
# Out:
# Crops Based on Specific Conditions
# ---------------------------------------------------------------
# Crops requiring very high nitrogen content (N > 120): ['cotton']
# Crops requiring very high phosphorous content (P > 100): ['grapes' 'apple']
# Crops requiring very high potassium content (K > 200): ['grapes' 'apple']
# Crops requiring very high rainfall (rainfall > 200mm): ['rice' 'papaya' 'coconut']
# Crops requiring very low temperature (temperature < 10°C): ['grapes']
# Crops requiring very high temperature (temperature > 40°C): ['grapes' 'papaya']
# Crops requiring very low humidity (humidity < 20%): ['chickpea' 'kidneybeans']
# Crops requiring very low pH (pH < 4): ['mothbeans']
# Crops requiring very high pH (pH > 9): ['mothbeans']

# %% [markdown]
# <h1>Ideal Crops for Different Seasons</h1>

# %%
#Filter the crops that are ideal for each season

print ("Summer Crops")
print(df[(df['temperature'] > 30) & (df['humidity'] > 50)]['label'].unique())
print("*--------------*----------------*")
print("Winter Crops")
print(df[(df['temperature'] < 20) & (df['humidity'] >30)]['label'].unique())
print("*---------------*----------------*")
print("Rainy Crops")
print(df[(df['rainfall'] > 200) & (df['humidity'] > 30)]['label'].unique())
# Out:
# Summer Crops
# ['pigeonpeas' 'mothbeans' 'blackgram' 'mango' 'grapes' 'orange' 'papaya']
# *--------------*----------------*
# Winter Crops
# ['maize' 'pigeonpeas' 'lentil' 'pomegranate' 'grapes' 'orange']
# *---------------*----------------*
# Rainy Crops
# ['rice' 'papaya' 'coconut']

# %%
#Find the crops which need similar climatic conditions and mineral requirements, and club them together using Clustering Analysis

from sklearn.cluster import KMeans
x=df.drop(['label'],axis=1)
x=x.values

print(x.shape)
# Out:
# (2200, 7)

# %%
#The Elbow Algorithm find the optimum number of Clusters required

plt.rcParams['figure.figsize']=(10,4)

wcss=[]

for i in range(1,11):
    km=KMeans(n_clusters=i,init = 'k-means++',max_iter=300, n_init=10,random_state =0)
    km.fit(x)
    wcss.append(km.inertia_)
    
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method',fontsize=20)
plt.xlabel('No of Clusters')
plt.ylabel("wcss")
plt.show()

# %%
#Select always the las Elbow: Hence our Cluster should be 4

#Apply Kmeans and check the Cluster of each crop: These helps Farmers to adopting similar kind of crops and yield maximum productivity
km = KMeans(n_clusters=4,init='k-means++',max_iter = 300,n_init=10,random_state=0)
y_means =km.fit_predict(x)

a=df['label']
y_means=pd.DataFrame(y_means)
z=pd.concat([y_means,a],axis=1)
z=z.rename(columns={0:'cluster'})

print(" Lets check the Results After Applying the K Means Clustering Analysis \n")
print("Crops in First Cluster:", z[z['cluster']==0]['label'].unique())
print("--------------------------------------------------------------")
print(" Crops in Second cluster:", z[z['cluster']==1]['label'].unique())
print('---------------------------------------------------------------')
print("Crops in Third cluster:", z[z['cluster'] ==2]['label'].unique())
print("----------------------------------------------------------------")
print("Crops in Forth Cluster:",z[z['cluster']==3]['label'].unique())
# Out:
#  Lets check the Results After Applying the K Means Clustering Analysis
#
# Crops in First Cluster: ['grapes' 'apple']
# --------------------------------------------------------------
#  Crops in Second cluster: ['maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans' 'mungbean'
#  'blackgram' 'lentil' 'pomegranate' 'mango' 'orange' 'papaya' 'coconut']
# ---------------------------------------------------------------
# Crops in Third cluster: ['maize' 'banana' 'watermelon' 'muskmelon' 'papaya' 'cotton' 'coffee']
# ----------------------------------------------------------------
# Crops in Forth Cluster: ['rice' 'pigeonpeas' 'papaya' 'coconut' 'jute' 'coffee']

# %%
#Them we train our model without labels, to avoid that our accuracy declines

y=df['label'] 
x=df.drop(['label'],axis=1)
print("Shape of x:",x.shape)
print("Shape of y:",y.shape)
# Out:
# Shape of x: (2200, 7)
# Shape of y: (2200,)

# %%
#Divide the Data into two sets; train_data and test_data
# 80% Data will be alotted into trainins set & remaining 20% will be sent into testing set

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2,random_state=0)

print("The Shape of x train:",x_train.shape)
print("The Shape of x test:",x_test.shape)
print("The Shape of y train:",y_train.shape)
print("The Shape of y test:",y_test.shape)
# Out:
# The Shape of x train: (1760, 7)
# The Shape of x test: (440, 7)
# The Shape of y train: (1760,)
# The Shape of y test: (440,)

# %%
#Time to build a predictior model; which grides us about the best productive crop as per the climatic and minerals condition, using machine learning to train our model

#We use Logistic Regression algorythm in this case because is a probalistic model; Suitable for multiple class types; We have 22 classes in our cases

from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(solver = 'liblinear')

model=model.fit(x_train, y_train)

y_pred = model.predict(x_test)

#Model trained

# %%
#Model's performance

from sklearn.metrics import confusion_matrix

# %%
plt.rcParams['figure.figsize']=(10,10)
cm = confusion_matrix(y_test, y_pred)
sb.heatmap(cm, annot =True, cmap ='Wistia')
plt.title("Confusion Matrix for Logistic Regression",fontsize = 15)
plt.show()

# %% [markdown]
# <h1>Classification Report and Model Accuracy</h1>

# %%
#To print the classification report (Accuracy)

from sklearn.metrics import classification_report
cr=classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        23
#       banana       0.95      1.00      0.98        21
#    blackgram       0.95      0.90      0.92        20
#     chickpea       1.00      1.00      1.00        26
#      coconut       1.00      1.00      1.00        27
#       coffee       0.85      1.00      0.92        17
#       cotton       0.94      0.94      0.94        17
#       grapes       1.00      1.00      1.00        14
#         jute       1.00      0.57      0.72        23
#  kidneybeans       0.90      0.95      0.93        20
#       lentil       0.85      1.00      0.92        11
#        maize       1.00      0.95      0.98        21
#        mango       0.76      1.00      0.86        19
#    mothbeans       1.00      0.71      0.83        24
#     mungbean       0.86      1.00      0.93        19
#    muskmelon       1.00      1.00      1.00        17
# ...

# %%
#By the classification report we get Precision and Recall very otimum, indicating strong accuracy of our training model with 96% of accuracy

df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %% [markdown]
# <h1>Predicting Crops</h1>

# %%
#Checking our model in specific soil and climate conditions
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

prediction = model.predict((np.array([[71, #for Nitrogen
                                      54,  #for Phosphorous
                                      16,  #for potassium
                                      22.613,  #for temperature
                                      63.6907,  #for humidity
                                      5.7499,   #for ph
                                      87.7595]])))#for Rainfall
print("The suggested crop for given climatic condition is:",prediction)
# Out:
# The suggested crop for given climatic condition is: ['maize']

# %%
#Checking our model in specific soil and climate conditions
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

prediction = model.predict((np.array([[90, #for Nitrogen
                                      42,  #for Phosphorous
                                      43,  #for potassium
                                      20.879,  #for temperature
                                      82.002,  #for humidity
                                      6.502,   #for ph
                                      202.935]])))#for Rainfall
print("The suggested crop for given climatic condition is:",prediction)
# Out:
# The suggested crop for given climatic condition is: ['rice']

# %%
#Checking our model in specific soil and climate conditions
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

prediction = model.predict((np.array([[25, #for Nitrogen
                                      50,  #for Phosphorous
                                      25,  #for potassium
                                      25.0,  #for temperature
                                      80.002,  #for humidity
                                      6.502,   #for ph
                                      200.935]])))#for Rainfall
print("The suggested crop for given climatic condition is:",prediction)
# Out:
# The suggested crop for given climatic condition is: ['pigeonpeas']

# %%
print(model)
# Out:
# LogisticRegression(solver='liblinear')

# %%
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Load dataset
df = pd.read_csv("Crop_recommendation.csv")

# Features (X) and target (y)
X = df.drop(columns=["label"])
y = df["label"]

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Train Logistic Regression model
crop_model = LogisticRegression(solver="liblinear")
crop_model.fit(X_train, y_train)

# Evaluate model
y_pred = crop_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Crop Model Accuracy: {accuracy * 100:.2f}%")

# Save model with scaler
with open("backend/model_crop.pkl", "wb") as f:
    pickle.dump({"model": crop_model, "scaler": scaler, "columns": X.columns.tolist()}, f)

print("Crop Model & Preprocessing saved successfully!")
# Out:
# Crop Model Accuracy: 92.95%
# Crop Model & Preprocessing saved successfully!
